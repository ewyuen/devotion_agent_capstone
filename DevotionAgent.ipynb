# %% [markdown]
# ## Setup & Imports

# %%
import xml.etree.ElementTree as ET
from typing import List, Dict
from datetime import datetime
from devotion_tools import get_today_devotion, DevotionSession
from ipywidgets import Textarea, Button, VBox, HTML
from IPython.display import display, clear_output

# %%
from dotenv import load_dotenv
import os
from google.adk.agents import LlmAgent
from google.adk.runners import InMemoryRunner
from google.genai import types

# Load environment variables from .env file
load_dotenv()

# Access environment variables
api_key = os.getenv("API_KEY")
model_name = os.getenv("MODEL_NAME", "gemini-2.0-flash")

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
get_today_devotion()
# Out:
# {'status': 'success',
#  'devotions': [{'book': '2Peter',
#    'start_chapter': '2',
#    'start_verse': '1',
#    'end_chapter': '2',
#    'end_verse': '22',
#    'type': 'NT',
#    'order': '0'},
#   {'book': 'Daniel',
#    'start_chapter': '5',
#    'start_verse': '1',
#    'end_chapter': '5',
#    'end_verse': '31',
#    'type': 'OT',
#    'order': '0'},
#   {'book': 'Proverbs',
#    'start_chapter': '28',
#    'start_verse': '19',
#    'end_chapter': '28',
#    'end_verse': '20',
#    'type': 'Proverbs',
#    'order': '0'},
#   {'book': 'Psalms',
#    'start_chapter': '132',
#    'start_verse': '1',
#    'end_chapter': '132',
#    'end_verse': '5',
#    'type': 'Psalms',
#    'order': '0'}],
#  'message': 'Successfully retrieved 4 devotion(s) for today',
#  'date': '2025-11-28',
#  'day_of_year': 332}

# %%
# Import agents and runners from devotion_agents module
from devotion_agents import (
    devotion_summary_agent, 
    devotion_runner,
    user_input_agent,
    user_input_runner,
    prayer_generator_agent,
    prayer_runner,
    worship_song_agent,
    worship_song_runner
)

# %% [markdown]
# ## Workflow Setup

# %%
from dataclasses import dataclass
from typing import Optional

@dataclass
class DevotionWorkflowResult:
    """Encapsulates the complete workflow execution result"""
    status: str  # "success" or "error"
    devotion_summary: Optional[str] = None
    user_input: Optional[str] = None
    prayer_response: Optional[str] = None
    worship_songs: Optional[str] = None
    error_message: Optional[str] = None
    timestamp: str = None
    
    def __post_init__(self):
        if not self.timestamp:
            self.timestamp = datetime.now().isoformat()

# %%
from ipywidgets import Textarea, Button, VBox, HTML, Output
from IPython.display import display, clear_output

# Global to store reflections
user_reflections_global = {'data': None}

def collect_user_input():
    """
    Collect user's personal reflection on the devotion using Jupyter widgets.
    """
    global user_reflections_global
    user_reflections_global['data'] = None
    
    print("\n" + "="*70)
    print("YOUR PERSONAL DEVOTION REFLECTION")
    print("="*70)
    print("\nShare your thoughts and reflections about today's devotion:\n")
    
    # Create a single text area for open-ended reflection
    print("What are your thoughts, insights, or how does this devotion apply to you?")
    textarea = Textarea(
        value='',
        placeholder='Type your reflection here...',
        description='',
        rows=6,
        layout={'width': '90%'}
    )
    display(textarea)
    
    # Create output widget for feedback
    output = Output()
    
    # Create a submit button
    submit_button = Button(description="Submit Reflection", button_style='success')
    display(submit_button)
    display(output)
    
    def on_submit_clicked(b):
        global user_reflections_global
        # Collect the response
        user_reflections_global['data'] = {
            'reflection': textarea.value
        }
        
        with output:
            clear_output()
            print("✓ Your reflection has been recorded.\n")
            print("Now run the next cell to continue the workflow.")
        
        # Disable button after submission
        submit_button.disabled = True
    
    submit_button.on_click(on_submit_clicked)

# %% [markdown]
# ## Complete Devotion Workflow
#
# Run the cell below to start the complete workflow. You'll submit your reflection and all subsequent steps will run automatically with clean output (no debug messages).

# %%
import uuid
from google.genai import Client

print("\nStarting DevotionAgent workflow...\n")

# Initialize session
devotion_session = DevotionSession()

# Initialize Gemini client
client = Client(api_key=os.getenv("API_KEY"))

# ============================================================
# STEP 1: DEVOTION SUMMARY
# ============================================================
print("[STEP 1/2] DEVOTION SUMMARY AGENT")
print("-" * 70)
print("Retrieving and summarizing today's devotion passages...\n")

# Get devotion data
devotion_data = get_today_devotion()

# Create prompt for devotion summary with actual devotion data
devotion_prompt = f"""Here are today's devotion passages:

{devotion_data}

Based on these passages, please provide:
1. A summary of each passage type (Psalms, Old Testament, New Testament, Proverbs)
2. 2-3 key Bible verses that support the message
3. Spiritual insights and themes

Format clearly with sections for each passage type."""

# Call Gemini directly
devotion_response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=devotion_prompt
)

devotion_summary = devotion_response.text

print("✓ Devotion summary retrieved\n")
print(devotion_summary)

devotion_session.save_devotion_summary(devotion_summary)
print("\n✓ Devotion summary saved to session")

# ============================================================
# STEP 2: COLLECT USER INPUT
# ============================================================
print("\n[STEP 2/2] COLLECT YOUR REFLECTION")
print("-" * 70)

# Show input form
collect_user_input()
# Out:
# Starting DevotionAgent workflow...
#
# [STEP 1/2] DEVOTION SUMMARY AGENT
# ----------------------------------------------------------------------
# Retrieving and summarizing today's devotion passages...
#
# ✓ Devotion summary retrieved
#
# Okay, here's a breakdown of the devotional passages, with summaries, key verses, and spiritual insights:
#
# **I. New Testament (2 Peter 2:1-22)**
#
# *   **Summary:** This passage warns against false teachers who will secretly introduce destructive heresies, denying the Lord Jesus and bringing swift destruction upon themselves. It describes their immoral conduct, greed, and exploitation of others. It contrasts their fate with God's judgment on the wicked in the past (angels who sinned, the world during Noah's flood, Sodom and Gomorrah) and his deliverance of the righteous (Noah, Lot). The chapter concludes by depicting the depravity and ultimate doom of these false teachers, comparing them to animals driven by instinct, and highlighting their hypocrisy and corruption.
# *   **Key Verses:**
#     *   2 Peter 2:1: "But there were also false prophets among the people, just as there will be false teachers among you. They will secretly introduce destructive heresies, even denying the sovereign Lord who bought them—bringing swift destruction on themselves." (Highlights the danger of false teaching)
#     *   2 Peter 2:20-22: "If they have escaped the corruption of the world by knowing our Lord and Savior Jesus Christ and are again entangled in it and are overcome, they are worse off at the end than they were at the beginning. It would have been better for them not to have known the way of righteousness, than to have known it and then to turn their backs on the sacred command that was passed on to them. Of them the proverbs are true: 'A dog returns to its vomit,' and 'A sow that is washed returns to her wallowing in the mud.'" (Warns of the danger of backsliding after knowing Christ).
# *   **Spiritual Insights and Themes:**
#     *   **Discernment:** The passage stresses the importance of discerning truth from error and being vigilant against false teachings.
#     *   **Judgment:** God will judge both the wicked and those who lead others astray.
#     *   **Holiness:** True faith should lead to a life of righteousness and separation from worldly corruption.
#     *   **Responsibility:** Believers have a responsibility to guard the truth and protect others from deception.
#     *   **Eternal Consequences:** Actions have eternal consequences.  Turning away from the known truth can be more devastating than never having known it.
#
# **II. Old Testament (Daniel 5:1-31)**
#
# *   **Summary:** This chapter recounts Belshazzar's feast, during which he profanes the sacred vessels taken from the temple in Jerusalem. As he and his nobles drink from them, a mysterious hand writes on the wall. Terrified, Belshazzar summons his wise men, but they cannot interpret the writing. Daniel is called in, and he rebukes Belshazzar for his arrogance and lack of reverence for God, reminding him of Nebuchadnezzar's humbling experience. Daniel interprets the writing as a prophecy of the downfall of Belshazzar's kingdom. That very night, Belshazzar is killed, and Darius the Mede takes over the kingdom.
# *   **Key Verses:**
#     *   Daniel 5:22-23: "But you, Belshazzar, his son, have not humbled yourself, though you knew all this. Instead, you have set yourself up against the Lord of heaven. You had the goblets from his temple brought to you, and you and your nobles, your wives and your concubines drank wine from them. You praised the gods of silver and gold, of bronze, iron, wood and stone, which cannot see or hear or understand. But you did not honor the God who holds in his hand your life and all your ways." (Highlights Belshazzar's pride and rejection of God)
#     *   Daniel 5:25-28: "This is the inscription that was written: MENE, MENE, TEKEL, PARSIN. Here is what these words mean: Mene: God has numbered the days of your reign and brought it to an end. Tekel: You have been weighed on the scales and found wanting. Peres: Your kingdom is divided and given to the Medes and Persians." (The interpretation of the writing, foretelling Belshazzar's doom)
# *   **Spiritual Insights and Themes:**
#     *   **Humility vs. Pride:** Belshazzar's pride and arrogance, in contrast to Nebuchadnezzar's eventual humility, demonstrate the importance of recognizing God's sovereignty.
#     *   **Accountability:** We are accountable to God for our actions, even if we are in positions of power.
#     *   **Profaning the Sacred:** Treating holy things with disrespect brings God's judgment.
#     *   **God's Sovereignty:** God is ultimately in control, and he can raise up or bring down kingdoms according to his will.
#     *   **Warning Against Arrogance:** Even knowing history can be futile if one fails to learn from it and humble themselves before God.
#
# **III. Proverbs (Proverbs 28:19-20)**
#
# *   **Summary:** These verses contrast the diligent farmer who will have plenty of food with the one who chases fantasies and will end up in poverty. They also highlight the trustworthiness of a faithful person versus the impatience and greed of one who wants to get rich quickly, and will not go unpunished.
# *   **Key Verses:**
#     *   Proverbs 28:19: "The one who works his land will have plenty of food, but the one who chases fantasies will have his fill of poverty." (Highlights the value of diligence and hard work.)
#     *   Proverbs 28:20: "A trustworthy person will receive lavish praise, but one in a hurry to get rich will not go unpunished." (Emphasizes the importance of integrity and warns against greed.)
# *   **Spiritual Insights and Themes:**
#     *   **Diligence and Hard Work:** Honest labor is rewarded, while laziness and chasing get-rich-quick schemes lead to ruin.
#     *   **Integrity and Trustworthiness:** Building trust and being faithful are more valuable than quick financial gain.
#     *   **Patience and Contentment:** Avoid the temptation to become wealthy quickly, as it often leads to dishonesty and negative consequences.
#     *   **Long-Term Perspective:** Focus on long-term values and sustainable practices rather than short-term gains.
#
# **IV. Psalms (Psalms 132:1-5)**
#
# *   **Summary:** This psalm expresses the psalmist's deep desire to find a suitable dwelling place for the Ark of the Covenant. It reflects on David's commitment and vow to the Lord to build a house for God, refusing to rest until he found a proper place for the Ark.
# *   **Key Verses:**
#     *   Psalm 132:3-5: "Surely I will not enter my house or go up to my bed, I will allow no sleep to my eyes, no slumber to my eyelids, till I find a place for the Lord, a dwelling for the Mighty One of Jacob." (Highlights David's unwavering commitment to honoring God.)
#     *   Psalm 132:1: "Lord, remember David and all the hardships he endured."
# *   **Spiritual Insights and Themes:**
#     *   **Zeal for God's House:** The passage reflects a deep desire to honor God and provide a worthy place for his presence.
#     *   **Commitment and Determination:** David's unwavering dedication demonstrates the importance of persevering in pursuing God's will.
#     *   **Worship and Reverence:** The psalm underscores the importance of creating a space for worship and honoring God in our lives.
#     *   **Remembering God's Servants:** It also reminds us to appreciate and learn from the examples of those who have faithfully served God in the past.
#     *   **Prioritizing God:** David's refusal to rest until God had a dwelling place shows a commitment to putting God first above personal comfort.
#
#
# ✓ Devotion summary saved to session
#
# [STEP 2/2] COLLECT YOUR REFLECTION
# ----------------------------------------------------------------------
#
# ======================================================================
# YOUR PERSONAL DEVOTION REFLECTION
# ======================================================================
#
# Share your thoughts and reflections about today's devotion:
#
# What are your thoughts, insights, or how does this devotion apply to you?
# Textarea(value='', layout=Layout(width='90%'), placeholder='Type your reflection here...', rows=6)
# Button(button_style='success', description='Submit Reflection', style=ButtonStyle())
# Output()

# %% [markdown]
# ## Continue After Reflection
#
# Click the cell below after submitting your reflection to complete the workflow with prayer and worship songs.

# %%
import os
from google.genai import Client

# Helper function to safely print any response type
def safe_print(obj):
    """Print any object type safely"""
    if isinstance(obj, list):
        print("\n".join(str(item) for item in obj))
    else:
        print(str(obj))

# Initialize Gemini client
client = Client(api_key=os.getenv("API_KEY"))

# Check if reflection was submitted
if user_reflections_global['data'] is None:
    print("❌ Please submit your reflection first by running the previous cell.")
else:
    user_reflections = user_reflections_global['data']
    devotion_session.save_user_reflection(user_reflections['reflection'])
    
    reflections_text = user_reflections['reflection']
    
    # ============================================================
    # STEP 3: PROCESS REFLECTION & GENERATE AFFIRMATION
    # ============================================================
    print("\n[STEP 3/4] PROCESSING YOUR REFLECTION & GENERATING AFFIRMATION")
    print("-" * 70)
    print("Creating affirmation and personalized prayer...\n")
    
    # Create a combined prompt for processing and prayer
    combined_prompt = f"""Based on this devotion summary:

{devotion_summary}

And this user's personal reflection:
{reflections_text}

Please provide:
1. A warm, affirming response to their reflection (100 words)
2. A personalized prayer (200 words) that incorporates the devotion themes and their reflection

Format the response clearly with sections for "Your Affirmation" and "Today's Prayer"."""
    
    # Call Gemini directly
    combined_response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=combined_prompt
    )
    
    combined_text = combined_response.text
    
    print("✓ Reflection processed and prayer generated\n")
    devotion_session.save_user_input_processing(combined_text)
    
    # ============================================================
    # STEP 4: DISCOVER WORSHIP SONGS
    # ============================================================
    print("\n[STEP 4/4] DISCOVERING WORSHIP SONGS")
    print("-" * 70)
    print("Finding worship songs that match today's spiritual themes...\n")
    
    # Create a worship prompt with context
    worship_prompt = f"""Based on this devotion:

{devotion_summary}

And this user reflection:
{reflections_text}

And this affirmation and prayer:
{combined_text}

Please recommend 5-7 worship songs that align with these themes. For each song, provide:
- Song title
- Artist name
- Spiritual theme
- YouTube search link

Format like this:
🎵 **[Song Title]** - [Artist]
   Theme: [Theme]
   https://www.youtube.com/results?search_query=[Song+Title]+[Artist]+worship"""
    
    # Call Gemini directly
    worship_response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=worship_prompt
    )
    
    worship_text = worship_response.text
    
    print("✓ Worship songs discovered\n")
    
    # ============================================================
    # DISPLAY RESULTS
    # ============================================================
    print("\n" + "="*70)
    print("COMPLETE DEVOTION WORKFLOW SUMMARY")
    print("="*70)
    
    print("\n[1] TODAY'S DEVOTION SUMMARY")
    print("-" * 70)
    safe_print(devotion_summary)
    
    print("\n[2] YOUR REFLECTION & AFFIRMATION")
    print("-" * 70)
    print("Your Reflection:")
    print(reflections_text)
    print("\n" + combined_text)
    
    print("\n[3] WORSHIP SONGS")
    print("-" * 70)
    safe_print(worship_text)
    
    print("\n" + "="*70)
    print("✓ DEVOTION AGENT WORKFLOW COMPLETED SUCCESSFULLY")
    print("="*70 + "\n")
# Out:
# [STEP 3/4] PROCESSING YOUR REFLECTION & GENERATING AFFIRMATION
# ----------------------------------------------------------------------
# Creating affirmation and personalized prayer...
#
# ✓ Reflection processed and prayer generated
#
#
# [STEP 4/4] DISCOVERING WORSHIP SONGS
# ----------------------------------------------------------------------
# Finding worship songs that match today's spiritual themes...
#
# ✓ Worship songs discovered
#
#
# ======================================================================
# COMPLETE DEVOTION WORKFLOW SUMMARY
# ======================================================================
#
# [1] TODAY'S DEVOTION SUMMARY
# ----------------------------------------------------------------------
# Okay, here's a breakdown of the devotional passages, with summaries, key verses, and spiritual insights:
#
# **I. New Testament (2 Peter 2:1-22)**
#
# *   **Summary:** This passage warns against false teachers who will secretly introduce destructive heresies, denying the Lord Jesus and bringing swift destruction upon themselves. It describes their immoral conduct, greed, and exploitation of others. It contrasts their fate with God's judgment on the wicked in the past (angels who sinned, the world during Noah's flood, Sodom and Gomorrah) and his deliverance of the righteous (Noah, Lot). The chapter concludes by depicting the depravity and ultimate doom of these false teachers, comparing them to animals driven by instinct, and highlighting their hypocrisy and corruption.
# *   **Key Verses:**
#     *   2 Peter 2:1: "But there were also false prophets among the people, just as there will be false teachers among you. They will secretly introduce destructive heresies, even denying the sovereign Lord who bought them—bringing swift destruction on themselves." (Highlights the danger of false teaching)
#     *   2 Peter 2:20-22: "If they have escaped the corruption of the world by knowing our Lord and Savior Jesus Christ and are again entangled in it and are overcome, they are worse off at the end than they were at the beginning. It would have been better for them not to have known the way of righteousness, than to have known it and then to turn their backs on the sacred command that was passed on to them. Of them the proverbs are true: 'A dog returns to its vomit,' and 'A sow that is washed returns to her wallowing in the mud.'" (Warns of the danger of backsliding after knowing Christ).
# *   **Spiritual Insights and Themes:**
#     *   **Discernment:** The passage stresses the importance of discerning truth from error and being vigilant against false teachings.
#     *   **Judgment:** God will judge both the wicked and those who lead others astray.
#     *   **Holiness:** True faith should lead to a life of righteousness and separation from worldly corruption.
#     *   **Responsibility:** Believers have a responsibility to guard the truth and protect others from deception.
#     *   **Eternal Consequences:** Actions have eternal consequences.  Turning away from the known truth can be more devastating than never having known it.
#
# **II. Old Testament (Daniel 5:1-31)**
#
# *   **Summary:** This chapter recounts Belshazzar's feast, during which he profanes the sacred vessels taken from the temple in Jerusalem. As he and his nobles drink from them, a mysterious hand writes on the wall. Terrified, Belshazzar summons his wise men, but they cannot interpret the writing. Daniel is called in, and he rebukes Belshazzar for his arrogance and lack of reverence for God, reminding him of Nebuchadnezzar's humbling experience. Daniel interprets the writing as a prophecy of the downfall of Belshazzar's kingdom. That very night, Belshazzar is killed, and Darius the Mede takes over the kingdom.
# *   **Key Verses:**
#     *   Daniel 5:22-23: "But you, Belshazzar, his son, have not humbled yourself, though you knew all this. Instead, you have set yourself up against the Lord of heaven. You had the goblets from his temple brought to you, and you and your nobles, your wives and your concubines drank wine from them. You praised the gods of silver and gold, of bronze, iron, wood and stone, which cannot see or hear or understand. But you did not honor the God who holds in his hand your life and all your ways." (Highlights Belshazzar's pride and rejection of God)
#     *   Daniel 5:25-28: "This is the inscription that was written: MENE, MENE, TEKEL, PARSIN. Here is what these words mean: Mene: God has numbered the days of your reign and brought it to an end. Tekel: You have been weighed on the scales and found wanting. Peres: Your kingdom is divided and given to the Medes and Persians." (The interpretation of the writing, foretelling Belshazzar's doom)
# *   **Spiritual Insights and Themes:**
#     *   **Humility vs. Pride:** Belshazzar's pride and arrogance, in contrast to Nebuchadnezzar's eventual humility, demonstrate the importance of recognizing God's sovereignty.
#     *   **Accountability:** We are accountable to God for our actions, even if we are in positions of power.
#     *   **Profaning the Sacred:** Treating holy things with disrespect brings God's judgment.
#     *   **God's Sovereignty:** God is ultimately in control, and he can raise up or bring down kingdoms according to his will.
#     *   **Warning Against Arrogance:** Even knowing history can be futile if one fails to learn from it and humble themselves before God.
#
# **III. Proverbs (Proverbs 28:19-20)**
#
# *   **Summary:** These verses contrast the diligent farmer who will have plenty of food with the one who chases fantasies and will end up in poverty. They also highlight the trustworthiness of a faithful person versus the impatience and greed of one who wants to get rich quickly, and will not go unpunished.
# *   **Key Verses:**
#     *   Proverbs 28:19: "The one who works his land will have plenty of food, but the one who chases fantasies will have his fill of poverty." (Highlights the value of diligence and hard work.)
#     *   Proverbs 28:20: "A trustworthy person will receive lavish praise, but one in a hurry to get rich will not go unpunished." (Emphasizes the importance of integrity and warns against greed.)
# *   **Spiritual Insights and Themes:**
#     *   **Diligence and Hard Work:** Honest labor is rewarded, while laziness and chasing get-rich-quick schemes lead to ruin.
#     *   **Integrity and Trustworthiness:** Building trust and being faithful are more valuable than quick financial gain.
#     *   **Patience and Contentment:** Avoid the temptation to become wealthy quickly, as it often leads to dishonesty and negative consequences.
#     *   **Long-Term Perspective:** Focus on long-term values and sustainable practices rather than short-term gains.
#
# **IV. Psalms (Psalms 132:1-5)**
#
# *   **Summary:** This psalm expresses the psalmist's deep desire to find a suitable dwelling place for the Ark of the Covenant. It reflects on David's commitment and vow to the Lord to build a house for God, refusing to rest until he found a proper place for the Ark.
# *   **Key Verses:**
#     *   Psalm 132:3-5: "Surely I will not enter my house or go up to my bed, I will allow no sleep to my eyes, no slumber to my eyelids, till I find a place for the Lord, a dwelling for the Mighty One of Jacob." (Highlights David's unwavering commitment to honoring God.)
#     *   Psalm 132:1: "Lord, remember David and all the hardships he endured."
# *   **Spiritual Insights and Themes:**
#     *   **Zeal for God's House:** The passage reflects a deep desire to honor God and provide a worthy place for his presence.
#     *   **Commitment and Determination:** David's unwavering dedication demonstrates the importance of persevering in pursuing God's will.
#     *   **Worship and Reverence:** The psalm underscores the importance of creating a space for worship and honoring God in our lives.
#     *   **Remembering God's Servants:** It also reminds us to appreciate and learn from the examples of those who have faithfully served God in the past.
#     *   **Prioritizing God:** David's refusal to rest until God had a dwelling place shows a commitment to putting God first above personal comfort.
#
#
# [2] YOUR REFLECTION & AFFIRMATION
# ----------------------------------------------------------------------
# Your Reflection:
# I love God
#
# Here's a response to your devotion summary and personal reflection:
#
# **Your Affirmation**
#
# It's wonderful to hear you say, "I love God." That simple statement is so powerful! It's clear from your reflection on these scriptures that you're actively seeking to deepen that love and understanding. The devotionals you've explored offer profound insights into living out that love in tangible ways – through discernment, integrity, humility, and a commitment to God's will. Your heart for God shines through, and it's a beautiful thing to witness. Keep pursuing that love and letting it shape your life. It's a journey worth taking, and one that brings great joy.
#
# **Today's Prayer**
#
# Heavenly Father, we come before you with hearts filled with gratitude and love, echoing the sentiment, "I love God." Lord, we thank you for the wisdom contained within your Word, the guidance in the scriptures we've reflected upon today. We ask for your help in discerning truth from error, guarding ourselves against false teachings and the allure of worldly corruption, as taught in 2 Peter. Give us the courage to stand firm in our faith and protect others from deception.
#
# Lord, remind us of Belshazzar's fate, and teach us to humble ourselves before you, recognizing your sovereignty in all things. Help us to avoid pride and arrogance, and to treat all that is sacred with reverence.
#
# As we consider the wisdom in Proverbs, grant us diligence and integrity in our work and relationships. Guard us from chasing quick riches and instead instill in us a desire for lasting value built on trust.
#
# Finally, Lord, inspire in us the same zeal that David had to find a place for your presence in our lives. May we prioritize you above all else, seeking your will in every decision we make. May this prayer guide us so we can better reflect your love, in Jesus' name, Amen.
#
#
# [3] WORSHIP SONGS
# ----------------------------------------------------------------------
# Here are 6 worship songs that align with the themes from the devotion, user reflection, affirmation, and prayer, formatted as requested:
#
# 🎵 **"Goodness of God"** - Bethel Music (feat. Jenn Johnson)
#    Theme: God's unwavering faithfulness, even in the face of hardship. Reflects the psalmist's commitment and the ultimate sovereignty of God.
#    https://www.youtube.com/results?search_query=Goodness+of+God+Bethel+Music+worship
#
# 🎵 **"What a Beautiful Name"** - Hillsong Worship
#    Theme: Reverence for God's holy name, and the power of Jesus Christ as a defense against the forces of darkness. Touches on themes of holiness and the importance of worshipping the one true God.
#    https://www.youtube.com/results?search_query=What+a+Beautiful+Name+Hillsong+Worship
#
# 🎵 **"Build My Life"** - Pat Barrett
#    Theme: Building your life on a foundation of trust in God's word and character. Aligns with the Proverbs theme of diligence and trustworthiness.
#    https://www.youtube.com/results?search_query=Build+My+Life+Pat+Barrett+worship
#
# 🎵 **"Lord, I Need You"** - Matt Maher
#    Theme: Recognizing dependence on God and humbling oneself before Him.  A good reminder against pride and a call for God's guidance, paralleling Belshazzar's downfall.
#    https://www.youtube.com/results?search_query=Lord+I+Need+You+Matt+Maher+worship
#
# 🎵 **"Living Hope"** - Phil Wickham
#    Theme: Redemption from corruption through Jesus, offering hope and a new identity in Christ. Connects with the 2 Peter warning about returning to corruption and the power of knowing Christ.
#    https://www.youtube.com/results?search_query=Living+Hope+Phil+Wickham+worship
#
# 🎵 **"King of My Heart"** - Bethel Music
#    Theme: Placing God as the supreme priority and source of joy in life. Captures the essence of David's desire to find a place for the Lord and the user's statement of loving God.
#    https://www.youtube.com/results?search_query=King+of+My+Heart+Bethel+Music+worship
#
#
# ======================================================================
# ✓ DEVOTION AGENT WORKFLOW COMPLETED SUCCESSFULLY
# ======================================================================
