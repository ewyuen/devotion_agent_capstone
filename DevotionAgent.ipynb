# %% [markdown]
# ## Setup & Imports

# %%
import xml.etree.ElementTree as ET
from typing import List, Dict
from datetime import datetime
from devotion_tools import get_today_devotion, DevotionSession
from ipywidgets import Textarea, Button, VBox, HTML
from IPython.display import display, clear_output

# %%
from dotenv import load_dotenv
import os
from google.adk.agents import LlmAgent
from google.adk.runners import InMemoryRunner
from google.genai import types

# Load environment variables from .env file
load_dotenv()

# Access environment variables
api_key = os.getenv("API_KEY")
model_name = os.getenv("MODEL_NAME", "gemini-2.0-flash")

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
get_today_devotion()
# Out:
# {'status': 'success',
#  'devotions': [{'book': '2Peter',
#    'start_chapter': '2',
#    'start_verse': '1',
#    'end_chapter': '2',
#    'end_verse': '22',
#    'type': 'NT',
#    'order': '0'},
#   {'book': 'Daniel',
#    'start_chapter': '5',
#    'start_verse': '1',
#    'end_chapter': '5',
#    'end_verse': '31',
#    'type': 'OT',
#    'order': '0'},
#   {'book': 'Proverbs',
#    'start_chapter': '28',
#    'start_verse': '19',
#    'end_chapter': '28',
#    'end_verse': '20',
#    'type': 'Proverbs',
#    'order': '0'},
#   {'book': 'Psalms',
#    'start_chapter': '132',
#    'start_verse': '1',
#    'end_chapter': '132',
#    'end_verse': '5',
#    'type': 'Psalms',
#    'order': '0'}],
#  'message': 'Successfully retrieved 4 devotion(s) for today',
#  'date': '2025-11-28',
#  'day_of_year': 332}

# %%
# Import agents and runners from devotion_agents module
from devotion_agents import (
    devotion_summary_agent, 
    devotion_runner,
    user_input_agent,
    user_input_runner,
    prayer_generator_agent,
    prayer_runner,
    worship_song_agent,
    worship_song_runner
)

# %% [markdown]
# ## Workflow Setup

# %%
from dataclasses import dataclass
from typing import Optional

@dataclass
class DevotionWorkflowResult:
    """Encapsulates the complete workflow execution result"""
    status: str  # "success" or "error"
    devotion_summary: Optional[str] = None
    user_input: Optional[str] = None
    prayer_response: Optional[str] = None
    worship_songs: Optional[str] = None
    error_message: Optional[str] = None
    timestamp: str = None
    
    def __post_init__(self):
        if not self.timestamp:
            self.timestamp = datetime.now().isoformat()

# %%
from ipywidgets import Textarea, Button, VBox, HTML, Output
from IPython.display import display, clear_output

# Global to store reflections
user_reflections_global = {'data': None}

def collect_user_input():
    """
    Collect user's personal reflection on the devotion using Jupyter widgets.
    """
    global user_reflections_global
    user_reflections_global['data'] = None
    
    print("\n" + "="*70)
    print("YOUR PERSONAL DEVOTION REFLECTION")
    print("="*70)
    print("\nShare your thoughts and reflections about today's devotion:\n")
    
    # Create a single text area for open-ended reflection
    print("What are your thoughts, insights, or how does this devotion apply to you?")
    textarea = Textarea(
        value='',
        placeholder='Type your reflection here...',
        description='',
        rows=6,
        layout={'width': '90%'}
    )
    display(textarea)
    
    # Create output widget for feedback
    output = Output()
    
    # Create a submit button
    submit_button = Button(description="Submit Reflection", button_style='success')
    display(submit_button)
    display(output)
    
    def on_submit_clicked(b):
        global user_reflections_global
        # Collect the response
        user_reflections_global['data'] = {
            'reflection': textarea.value
        }
        
        with output:
            clear_output()
            print("✓ Your reflection has been recorded.\n")
            print("Now run the next cell to continue the workflow.")
        
        # Disable button after submission
        submit_button.disabled = True
    
    submit_button.on_click(on_submit_clicked)

# %% [markdown]
# ## Complete Devotion Workflow
#
# Run the cell below to start the complete workflow. You'll submit your reflection and all subsequent steps will run automatically with clean output (no debug messages).

# %%
import uuid
from google.genai import Client

print("\nStarting DevotionAgent workflow...\n")

# Initialize session
devotion_session = DevotionSession()

# Initialize Gemini client
client = Client(api_key=os.getenv("API_KEY"))

# ============================================================
# STEP 1: DEVOTION SUMMARY
# ============================================================
print("[STEP 1/2] DEVOTION SUMMARY AGENT")
print("-" * 70)
print("Retrieving and summarizing today's devotion passages...\n")

# Get devotion data
devotion_data = get_today_devotion()

# Create prompt for devotion summary with actual devotion data
devotion_prompt = f"""Here are today's devotion passages:

{devotion_data}

Based on these passages, please provide:
1. A summary of each passage type (Psalms, Old Testament, New Testament, Proverbs)
2. 2-3 key Bible verses that support the message
3. Spiritual insights and themes

Format clearly with sections for each passage type."""

# Call Gemini directly
devotion_response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents=devotion_prompt
)

devotion_summary = devotion_response.text

print("✓ Devotion summary retrieved\n")
print(devotion_summary)

devotion_session.save_devotion_summary(devotion_summary)
print("\n✓ Devotion summary saved to session")

# ============================================================
# STEP 2: COLLECT USER INPUT
# ============================================================
print("\n[STEP 2/2] COLLECT YOUR REFLECTION")
print("-" * 70)

# Show input form
collect_user_input()
# Out:
# Starting DevotionAgent workflow...
#
# [STEP 1/2] DEVOTION SUMMARY AGENT
# ----------------------------------------------------------------------
# Retrieving and summarizing today's devotion passages...
#
# ✓ Devotion summary retrieved
#
# Okay, here's a breakdown of the devotion passages you provided, including summaries, key verses, and spiritual insights:
#
# **New Testament: 2 Peter 2:1-22**
#
# *   **Summary:** This passage warns against false teachers and prophets who will introduce destructive heresies and exploit believers through their greed. It describes their corrupt character and the judgment that awaits them, drawing parallels to Old Testament examples like the fallen angels, Noah's flood, and the destruction of Sodom and Gomorrah. It highlights their immoral behavior, arrogance, and empty promises, leading people astray and back into sin. Ultimately, it concludes that it would have been better for them to never have known the way of righteousness than to turn away from the holy command delivered to them.
#
# *   **Key Verses:**
#
#     *   2 Peter 2:1: "But there were also false prophets among the people, just as there will be false teachers among you. They will secretly introduce destructive heresies, even denying the sovereign Lord who bought them—bringing swift destruction on themselves."
#     *   2 Peter 2:20-22: "If they have escaped the corruption of the world by knowing our Lord and Savior Jesus Christ and are again entangled in it and are overcome, they are worse off at the end than they were at the beginning. It would have been better for them not to have known the way of righteousness, than to have known it and then to turn their backs on the sacred command that was passed on to them. Of them the proverbs are true: 'A dog returns to its vomit,' and, 'A sow that is washed returns to her wallowing in the mud.'"
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Discernment:** The passage emphasizes the importance of discerning true teachers from false ones. We must be vigilant in examining their teachings and character in light of Scripture.
#     *   **The Danger of Apostasy:** It highlights the serious consequences of turning away from the truth after having known it. Genuine salvation should produce lasting fruit, and those who abandon their faith demonstrate that their initial profession was not genuine.
#     *   **God's Judgment:** God will judge false teachers and those who follow them. He is just and will hold them accountable for leading others astray.
#     *   **The Reality of Spiritual Warfare:** There is an ongoing battle against deceptive forces trying to undermine faith and lead people down destructive paths.
#
# **Old Testament: Daniel 5:1-31**
#
# *   **Summary:** This chapter recounts Belshazzar's feast, where he profanes the sacred vessels taken from the Temple in Jerusalem. During the feast, a mysterious hand appears and writes a message on the wall. Unable to interpret it, Belshazzar summons Daniel, who rebukes the king for his arrogance and failure to learn from Nebuchadnezzar's experience. Daniel interprets the writing: "Mene, Mene, Tekel, Parsin," meaning that God has numbered Belshazzar's kingdom, weighed him on the scales and found him wanting, and divided his kingdom. That very night, Belshazzar is killed, and Darius the Mede takes over the kingdom.
#
# *   **Key Verses:**
#
#     *   Daniel 5:22-23: "But you, Belshazzar, his son, have not humbled yourself, though you knew all this. Instead, you have set yourself up against the Lord of heaven. You had the goblets from his temple brought to you, and you and your nobles, your wives and your concubines drank wine from them. You praised the gods of silver and gold, of bronze, iron, wood and stone, which cannot see or hear or understand. But you did not honor the God who holds in his hand your life and all your ways."
#     *   Daniel 5:30-31: "That very night Belshazzar, king of the Babylonians, was slain, and Darius the Mede took over the kingdom, at the age of sixty-two."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Humility vs. Pride:** The story contrasts the humility of Nebuchadnezzar after his humbling experience with the arrogance of Belshazzar, which led to his downfall.
#     *   **The Sovereignty of God:** God is in control of kingdoms and rulers. He can raise them up and tear them down according to his will.
#     *   **Judgment and Accountability:** God sees all and holds individuals and nations accountable for their actions, especially when they defy him and profane what is sacred.
#     *   **Warning against Profanity:** Treating holy things with disrespect has consequences.
#
# **Proverbs: Proverbs 28:19-20**
#
# *   **Summary:** This passage presents two contrasting proverbs. The first states that those who work their land will have abundant food, but those who chase fantasies (or worthless pursuits) will have abundant poverty. The second states that a trustworthy person will be richly blessed, but one eager to get rich will not go unpunished.
#
# *   **Key Verses:**
#
#     *   Proverbs 28:19: "Those who work their land will have abundant food, but those who chase fantasies will have abundant poverty."
#     *   Proverbs 28:20: "A trustworthy person will be richly blessed, but one eager to get rich will not go unpunished."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Diligence and Hard Work:** It emphasizes the value of hard work, honest labor, and responsible stewardship of resources.
#     *   **Trustworthiness and Integrity:** It highlights the importance of integrity, honesty, and trustworthiness in our dealings with others.
#     *   **The Dangers of Greed:** It warns against the pursuit of wealth through dishonest or unethical means. Quick riches often lead to ruin.
#     *   **Contentment:** True wealth and satisfaction are found not in chasing fantasies, but in diligent work and trustworthy character.
#
# **Psalms: Psalms 132:1-5**
#
# *   **Summary:** This Psalm is a prayer recalling David's vow to find a suitable place for the Ark of the Covenant to dwell. It speaks of David's zeal and dedication to God, as he was not content to rest or relax until he had found a permanent home for the Ark, symbolizing God's presence, in Jerusalem.
#
# *   **Key Verses:**
#
#     *   Psalm 132:4-5: "I will allow no sleep to my eyes, no slumber to my eyelids, till I find a place for the Lord, a dwelling for the Mighty One of Jacob.”
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Zeal for God's Presence:** David's devotion demonstrates a deep desire for God's presence and a commitment to honoring Him.
#     *   **Prioritizing God's Will:** David's example teaches us to prioritize God's will above our own comfort and personal desires.
#     *   **Worship and Dedication:** It highlights the importance of finding a suitable place for God in our lives and our willingness to dedicate our time, energy, and resources to His service.
#     *   **Persistence in Seeking God:** David's vow reflects a persistent pursuit of God and a determination to fulfill his commitment.
#
#
# ✓ Devotion summary saved to session
#
# [STEP 2/2] COLLECT YOUR REFLECTION
# ----------------------------------------------------------------------
#
# ======================================================================
# YOUR PERSONAL DEVOTION REFLECTION
# ======================================================================
#
# Share your thoughts and reflections about today's devotion:
#
# What are your thoughts, insights, or how does this devotion apply to you?
# ✓ Devotion summary retrieved
#
# Okay, here's a breakdown of the devotion passages you provided, including summaries, key verses, and spiritual insights:
#
# **New Testament: 2 Peter 2:1-22**
#
# *   **Summary:** This passage warns against false teachers and prophets who will introduce destructive heresies and exploit believers through their greed. It describes their corrupt character and the judgment that awaits them, drawing parallels to Old Testament examples like the fallen angels, Noah's flood, and the destruction of Sodom and Gomorrah. It highlights their immoral behavior, arrogance, and empty promises, leading people astray and back into sin. Ultimately, it concludes that it would have been better for them to never have known the way of righteousness than to turn away from the holy command delivered to them.
#
# *   **Key Verses:**
#
#     *   2 Peter 2:1: "But there were also false prophets among the people, just as there will be false teachers among you. They will secretly introduce destructive heresies, even denying the sovereign Lord who bought them—bringing swift destruction on themselves."
#     *   2 Peter 2:20-22: "If they have escaped the corruption of the world by knowing our Lord and Savior Jesus Christ and are again entangled in it and are overcome, they are worse off at the end than they were at the beginning. It would have been better for them not to have known the way of righteousness, than to have known it and then to turn their backs on the sacred command that was passed on to them. Of them the proverbs are true: 'A dog returns to its vomit,' and, 'A sow that is washed returns to her wallowing in the mud.'"
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Discernment:** The passage emphasizes the importance of discerning true teachers from false ones. We must be vigilant in examining their teachings and character in light of Scripture.
#     *   **The Danger of Apostasy:** It highlights the serious consequences of turning away from the truth after having known it. Genuine salvation should produce lasting fruit, and those who abandon their faith demonstrate that their initial profession was not genuine.
#     *   **God's Judgment:** God will judge false teachers and those who follow them. He is just and will hold them accountable for leading others astray.
#     *   **The Reality of Spiritual Warfare:** There is an ongoing battle against deceptive forces trying to undermine faith and lead people down destructive paths.
#
# **Old Testament: Daniel 5:1-31**
#
# *   **Summary:** This chapter recounts Belshazzar's feast, where he profanes the sacred vessels taken from the Temple in Jerusalem. During the feast, a mysterious hand appears and writes a message on the wall. Unable to interpret it, Belshazzar summons Daniel, who rebukes the king for his arrogance and failure to learn from Nebuchadnezzar's experience. Daniel interprets the writing: "Mene, Mene, Tekel, Parsin," meaning that God has numbered Belshazzar's kingdom, weighed him on the scales and found him wanting, and divided his kingdom. That very night, Belshazzar is killed, and Darius the Mede takes over the kingdom.
#
# *   **Key Verses:**
#
#     *   Daniel 5:22-23: "But you, Belshazzar, his son, have not humbled yourself, though you knew all this. Instead, you have set yourself up against the Lord of heaven. You had the goblets from his temple brought to you, and you and your nobles, your wives and your concubines drank wine from them. You praised the gods of silver and gold, of bronze, iron, wood and stone, which cannot see or hear or understand. But you did not honor the God who holds in his hand your life and all your ways."
#     *   Daniel 5:30-31: "That very night Belshazzar, king of the Babylonians, was slain, and Darius the Mede took over the kingdom, at the age of sixty-two."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Humility vs. Pride:** The story contrasts the humility of Nebuchadnezzar after his humbling experience with the arrogance of Belshazzar, which led to his downfall.
#     *   **The Sovereignty of God:** God is in control of kingdoms and rulers. He can raise them up and tear them down according to his will.
#     *   **Judgment and Accountability:** God sees all and holds individuals and nations accountable for their actions, especially when they defy him and profane what is sacred.
#     *   **Warning against Profanity:** Treating holy things with disrespect has consequences.
#
# **Proverbs: Proverbs 28:19-20**
#
# *   **Summary:** This passage presents two contrasting proverbs. The first states that those who work their land will have abundant food, but those who chase fantasies (or worthless pursuits) will have abundant poverty. The second states that a trustworthy person will be richly blessed, but one eager to get rich will not go unpunished.
#
# *   **Key Verses:**
#
#     *   Proverbs 28:19: "Those who work their land will have abundant food, but those who chase fantasies will have abundant poverty."
#     *   Proverbs 28:20: "A trustworthy person will be richly blessed, but one eager to get rich will not go unpunished."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Diligence and Hard Work:** It emphasizes the value of hard work, honest labor, and responsible stewardship of resources.
#     *   **Trustworthiness and Integrity:** It highlights the importance of integrity, honesty, and trustworthiness in our dealings with others.
#     *   **The Dangers of Greed:** It warns against the pursuit of wealth through dishonest or unethical means. Quick riches often lead to ruin.
#     *   **Contentment:** True wealth and satisfaction are found not in chasing fantasies, but in diligent work and trustworthy character.
#
# **Psalms: Psalms 132:1-5**
#
# *   **Summary:** This Psalm is a prayer recalling David's vow to find a suitable place for the Ark of the Covenant to dwell. It speaks of David's zeal and dedication to God, as he was not content to rest or relax until he had found a permanent home for the Ark, symbolizing God's presence, in Jerusalem.
#
# *   **Key Verses:**
#
#     *   Psalm 132:4-5: "I will allow no sleep to my eyes, no slumber to my eyelids, till I find a place for the Lord, a dwelling for the Mighty One of Jacob.”
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Zeal for God's Presence:** David's devotion demonstrates a deep desire for God's presence and a commitment to honoring Him.
#     *   **Prioritizing God's Will:** David's example teaches us to prioritize God's will above our own comfort and personal desires.
#     *   **Worship and Dedication:** It highlights the importance of finding a suitable place for God in our lives and our willingness to dedicate our time, energy, and resources to His service.
#     *   **Persistence in Seeking God:** David's vow reflects a persistent pursuit of God and a determination to fulfill his commitment.
#
#
# ✓ Devotion summary saved to session
#
# [STEP 2/2] COLLECT YOUR REFLECTION
# ----------------------------------------------------------------------
#
# ======================================================================
# YOUR PERSONAL DEVOTION REFLECTION
# ======================================================================
#
# Share your thoughts and reflections about today's devotion:
#
# What are your thoughts, insights, or how does this devotion apply to you?
# Textarea(value='', layout=Layout(width='90%'), placeholder='Type your reflection here...', rows=6)
# Button(button_style='success', description='Submit Reflection', style=ButtonStyle())
# Output()

# %% [markdown]
# ## Continue After Reflection
#
# Click the cell below after submitting your reflection to complete the workflow with prayer and worship songs.

# %%
import os
from google.genai import Client

# Helper function to safely print any response type
def safe_print(obj):
    """Print any object type safely"""
    if isinstance(obj, list):
        print("\n".join(str(item) for item in obj))
    else:
        print(str(obj))

# Initialize Gemini client
client = Client(api_key=os.getenv("API_KEY"))

# Check if reflection was submitted
if user_reflections_global['data'] is None:
    print("❌ Please submit your reflection first by running the previous cell.")
else:
    user_reflections = user_reflections_global['data']
    devotion_session.save_user_reflection(user_reflections['reflection'])
    
    reflections_text = user_reflections['reflection']
    
    # ============================================================
    # STEP 3: PROCESS REFLECTION & GENERATE AFFIRMATION
    # ============================================================
    print("\n[STEP 3/4] PROCESSING YOUR REFLECTION & GENERATING AFFIRMATION")
    print("-" * 70)
    print("Creating affirmation and personalized prayer...\n")
    
    # Create a combined prompt for processing and prayer
    combined_prompt = f"""Based on this devotion summary:

{devotion_summary}

And this user's personal reflection:
{reflections_text}

Please provide:
1. A warm, affirming response to their reflection (100 words)
2. A personalized prayer (200 words) that incorporates the devotion themes and their reflection

Format the response clearly with sections for "Your Affirmation" and "Today's Prayer"."""
    
    # Call Gemini directly
    combined_response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=combined_prompt
    )
    
    combined_text = combined_response.text
    
    print("✓ Reflection processed and prayer generated\n")
    devotion_session.save_user_input_processing(combined_text)
    
    # ============================================================
    # STEP 4: DISCOVER WORSHIP SONGS
    # ============================================================
    print("\n[STEP 4/4] DISCOVERING WORSHIP SONGS")
    print("-" * 70)
    print("Finding worship songs that match today's spiritual themes...\n")
    
    # Create a worship prompt with context
    worship_prompt = f"""Based on this devotion:

{devotion_summary}

And this user reflection:
{reflections_text}

And this affirmation and prayer:
{combined_text}

Please recommend 5-7 worship songs that align with these themes. For each song, provide:
- Song title
- Artist name
- Spiritual theme
- YouTube search link

Format like this:
🎵 **[Song Title]** - [Artist]
   Theme: [Theme]
   https://www.youtube.com/results?search_query=[Song+Title]+[Artist]+worship"""
    
    # Call Gemini directly
    worship_response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=worship_prompt
    )
    
    worship_text = worship_response.text
    
    print("✓ Worship songs discovered\n")
    
    # ============================================================
    # DISPLAY RESULTS
    # ============================================================
    print("\n" + "="*70)
    print("COMPLETE DEVOTION WORKFLOW SUMMARY")
    print("="*70)
    
    print("\n[1] TODAY'S DEVOTION SUMMARY")
    print("-" * 70)
    safe_print(devotion_summary)
    
    print("\n[2] YOUR REFLECTION & AFFIRMATION")
    print("-" * 70)
    print("Your Reflection:")
    print(reflections_text)
    print("\n" + combined_text)
    
    print("\n[3] WORSHIP SONGS")
    print("-" * 70)
    safe_print(worship_text)
    
    print("\n" + "="*70)
    print("✓ DEVOTION AGENT WORKFLOW COMPLETED SUCCESSFULLY")
    print("="*70 + "\n")
# Out:
# [STEP 3/4] PROCESSING YOUR REFLECTION & GENERATING AFFIRMATION
# ----------------------------------------------------------------------
# Creating affirmation and personalized prayer...
#
# ✓ Reflection processed and prayer generated
#
#
# [STEP 4/4] DISCOVERING WORSHIP SONGS
# ----------------------------------------------------------------------
# Finding worship songs that match today's spiritual themes...
#
# ✓ Reflection processed and prayer generated
#
#
# [STEP 4/4] DISCOVERING WORSHIP SONGS
# ----------------------------------------------------------------------
# Finding worship songs that match today's spiritual themes...
#
# ✓ Worship songs discovered
#
#
# ======================================================================
# COMPLETE DEVOTION WORKFLOW SUMMARY
# ======================================================================
#
# [1] TODAY'S DEVOTION SUMMARY
# ----------------------------------------------------------------------
# Okay, here's a breakdown of the devotion passages you provided, including summaries, key verses, and spiritual insights:
#
# **New Testament: 2 Peter 2:1-22**
#
# *   **Summary:** This passage warns against false teachers and prophets who will introduce destructive heresies and exploit believers through their greed. It describes their corrupt character and the judgment that awaits them, drawing parallels to Old Testament examples like the fallen angels, Noah's flood, and the destruction of Sodom and Gomorrah. It highlights their immoral behavior, arrogance, and empty promises, leading people astray and back into sin. Ultimately, it concludes that it would have been better for them to never have known the way of righteousness than to turn away from the holy command delivered to them.
#
# *   **Key Verses:**
#
#     *   2 Peter 2:1: "But there were also false prophets among the people, just as there will be false teachers among you. They will secretly introduce destructive heresies, even denying the sovereign Lord who bought them—bringing swift destruction on themselves."
#     *   2 Peter 2:20-22: "If they have escaped the corruption of the world by knowing our Lord and Savior Jesus Christ and are again entangled in it and are overcome, they are worse off at the end than they were at the beginning. It would have been better for them not to have known the way of righteousness, than to have known it and then to turn their backs on the sacred command that was passed on to them. Of them the proverbs are true: 'A dog returns to its vomit,' and, 'A sow that is washed returns to her wallowing in the mud.'"
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Discernment:** The passage emphasizes the importance of discerning true teachers from false ones. We must be vigilant in examining their teachings and character in light of Scripture.
#     *   **The Danger of Apostasy:** It highlights the serious consequences of turning away from the truth after having known it. Genuine salvation should produce lasting fruit, and those who abandon their faith demonstrate that their initial profession was not genuine.
#     *   **God's Judgment:** God will judge false teachers and those who follow them. He is just and will hold them accountable for leading others astray.
#     *   **The Reality of Spiritual Warfare:** There is an ongoing battle against deceptive forces trying to undermine faith and lead people down destructive paths.
#
# **Old Testament: Daniel 5:1-31**
#
# *   **Summary:** This chapter recounts Belshazzar's feast, where he profanes the sacred vessels taken from the Temple in Jerusalem. During the feast, a mysterious hand appears and writes a message on the wall. Unable to interpret it, Belshazzar summons Daniel, who rebukes the king for his arrogance and failure to learn from Nebuchadnezzar's experience. Daniel interprets the writing: "Mene, Mene, Tekel, Parsin," meaning that God has numbered Belshazzar's kingdom, weighed him on the scales and found him wanting, and divided his kingdom. That very night, Belshazzar is killed, and Darius the Mede takes over the kingdom.
#
# *   **Key Verses:**
#
#     *   Daniel 5:22-23: "But you, Belshazzar, his son, have not humbled yourself, though you knew all this. Instead, you have set yourself up against the Lord of heaven. You had the goblets from his temple brought to you, and you and your nobles, your wives and your concubines drank wine from them. You praised the gods of silver and gold, of bronze, iron, wood and stone, which cannot see or hear or understand. But you did not honor the God who holds in his hand your life and all your ways."
#     *   Daniel 5:30-31: "That very night Belshazzar, king of the Babylonians, was slain, and Darius the Mede took over the kingdom, at the age of sixty-two."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Humility vs. Pride:** The story contrasts the humility of Nebuchadnezzar after his humbling experience with the arrogance of Belshazzar, which led to his downfall.
#     *   **The Sovereignty of God:** God is in control of kingdoms and rulers. He can raise them up and tear them down according to his will.
#     *   **Judgment and Accountability:** God sees all and holds individuals and nations accountable for their actions, especially when they defy him and profane what is sacred.
#     *   **Warning against Profanity:** Treating holy things with disrespect has consequences.
#
# **Proverbs: Proverbs 28:19-20**
#
# *   **Summary:** This passage presents two contrasting proverbs. The first states that those who work their land will have abundant food, but those who chase fantasies (or worthless pursuits) will have abundant poverty. The second states that a trustworthy person will be richly blessed, but one eager to get rich will not go unpunished.
#
# *   **Key Verses:**
#
#     *   Proverbs 28:19: "Those who work their land will have abundant food, but those who chase fantasies will have abundant poverty."
#     *   Proverbs 28:20: "A trustworthy person will be richly blessed, but one eager to get rich will not go unpunished."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Diligence and Hard Work:** It emphasizes the value of hard work, honest labor, and responsible stewardship of resources.
#     *   **Trustworthiness and Integrity:** It highlights the importance of integrity, honesty, and trustworthiness in our dealings with others.
#     *   **The Dangers of Greed:** It warns against the pursuit of wealth through dishonest or unethical means. Quick riches often lead to ruin.
#     *   **Contentment:** True wealth and satisfaction are found not in chasing fantasies, but in diligent work and trustworthy character.
#
# **Psalms: Psalms 132:1-5**
#
# *   **Summary:** This Psalm is a prayer recalling David's vow to find a suitable place for the Ark of the Covenant to dwell. It speaks of David's zeal and dedication to God, as he was not content to rest or relax until he had found a permanent home for the Ark, symbolizing God's presence, in Jerusalem.
#
# *   **Key Verses:**
#
#     *   Psalm 132:4-5: "I will allow no sleep to my eyes, no slumber to my eyelids, till I find a place for the Lord, a dwelling for the Mighty One of Jacob.”
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Zeal for God's Presence:** David's devotion demonstrates a deep desire for God's presence and a commitment to honoring Him.
#     *   **Prioritizing God's Will:** David's example teaches us to prioritize God's will above our own comfort and personal desires.
#     *   **Worship and Dedication:** It highlights the importance of finding a suitable place for God in our lives and our willingness to dedicate our time, energy, and resources to His service.
#     *   **Persistence in Seeking God:** David's vow reflects a persistent pursuit of God and a determination to fulfill his commitment.
#
#
# [2] YOUR REFLECTION & AFFIRMATION
# ----------------------------------------------------------------------
# Your Reflection:
# God is awesome
#
# Here's a personalized response and prayer based on the devotion summary and the user's reflection:
#
# **Your Affirmation**
#
# Yes, God *is* awesome! That simple statement encapsulates the profound truths we explored today. It’s amazing how each of these passages – from warnings about false teachers to Belshazzar's pride and David's zeal – points back to the same truth: God's power, justice, and love are unmatched. Keeping that at the center of our lives and decisions helps us navigate the world with wisdom and grace. You're right to focus on His awesomeness - it's the foundation of everything! Let that truth be your guide and comfort today.
#
# **Today's Prayer**
#
# Heavenly Father, thank you for your awesome power and grace, so clearly displayed throughout Scripture. We echo the simple, yet profound truth: "God is awesome!"
#
# Lord, help us to be discerning, as Peter warned, to recognize and reject false teachings that might lead us astray. Protect us from arrogance and pride, remembering Belshazzar's fate. Let us learn from the past and humble ourselves before you, acknowledging your sovereignty over all things.
#
# Grant us the diligence and trustworthiness described in Proverbs. May we be diligent in our work and ethical in our dealings, trusting that true riches come from honest labor and a commitment to integrity.
#
# Instill in us the same zeal for your presence that David had. Help us prioritize you in our lives, seeking to honor you in all that we do. Let us not be content until we have found a suitable place for you to dwell within our hearts and in our actions.
#
# Lord, guide us each day. May your awesomeness inspire us to live lives worthy of your calling. In Jesus' name, Amen.
#
#
# [3] WORSHIP SONGS
# ----------------------------------------------------------------------
# Okay, here are 6 worship songs that align with the themes found in the devotion passages, the user's reflection, and the prayer provided:
#
# 🎵 **"Awesome God"** - Rich Mullins
#    Theme: God's incredible power and majesty; a direct reflection of the "God is Awesome!" sentiment.
#    https://www.youtube.com/results?search_query=Awesome+God+Rich+Mullins+worship
#
# 🎵 **"King of My Heart"** - Bethel Music
#    Theme: Prioritizing God in your life, similar to David's zeal, and acknowledging God's sovereignty and goodness.
#    https://www.youtube.com/results?search_query=King+of+My+Heart+Bethel+worship
#
# 🎵 **"Build My Life"** - Housefires
#    Theme: Building your life upon a solid foundation of faith and being trustworthy, reflecting the Proverbs passage. Acknowledges that God is the only secure foundation.
#    https://www.youtube.com/results?search_query=Build+My+Life+Housefires+worship
#
# 🎵 **"What a Beautiful Name"** - Hillsong Worship
#    Theme: The power and majesty of God's name, especially the name of Jesus; humbling yourself before God and recognizing His supreme authority.
#    https://www.youtube.com/results?search_query=What+a+Beautiful+Name+Hillsong+worship
#
# 🎵 **"Lord, I Need You"** - Matt Maher
#    Theme: Dependence on God, humbling yourself before Him, and acknowledging your need for His guidance and strength, especially in times of temptation to follow false teachings.
#    https://www.youtube.com/results?search_query=Lord+I+Need+You+Matt+Maher+worship
#
# 🎵 **"Great Are You Lord"** - All Sons & Daughters
#    Theme: Acknowledging God's greatness and sovereignty, giving Him praise for His mighty works, and trusting in His faithfulness. Reflects the themes of humility and awe.
#    https://www.youtube.com/results?search_query=Great+Are+You+Lord+All+Sons+&+Daughters+worship
#
#
# ======================================================================
# ✓ DEVOTION AGENT WORKFLOW COMPLETED SUCCESSFULLY
# ======================================================================
#
# ✓ Worship songs discovered
#
#
# ======================================================================
# COMPLETE DEVOTION WORKFLOW SUMMARY
# ======================================================================
#
# [1] TODAY'S DEVOTION SUMMARY
# ----------------------------------------------------------------------
# Okay, here's a breakdown of the devotion passages you provided, including summaries, key verses, and spiritual insights:
#
# **New Testament: 2 Peter 2:1-22**
#
# *   **Summary:** This passage warns against false teachers and prophets who will introduce destructive heresies and exploit believers through their greed. It describes their corrupt character and the judgment that awaits them, drawing parallels to Old Testament examples like the fallen angels, Noah's flood, and the destruction of Sodom and Gomorrah. It highlights their immoral behavior, arrogance, and empty promises, leading people astray and back into sin. Ultimately, it concludes that it would have been better for them to never have known the way of righteousness than to turn away from the holy command delivered to them.
#
# *   **Key Verses:**
#
#     *   2 Peter 2:1: "But there were also false prophets among the people, just as there will be false teachers among you. They will secretly introduce destructive heresies, even denying the sovereign Lord who bought them—bringing swift destruction on themselves."
#     *   2 Peter 2:20-22: "If they have escaped the corruption of the world by knowing our Lord and Savior Jesus Christ and are again entangled in it and are overcome, they are worse off at the end than they were at the beginning. It would have been better for them not to have known the way of righteousness, than to have known it and then to turn their backs on the sacred command that was passed on to them. Of them the proverbs are true: 'A dog returns to its vomit,' and, 'A sow that is washed returns to her wallowing in the mud.'"
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Discernment:** The passage emphasizes the importance of discerning true teachers from false ones. We must be vigilant in examining their teachings and character in light of Scripture.
#     *   **The Danger of Apostasy:** It highlights the serious consequences of turning away from the truth after having known it. Genuine salvation should produce lasting fruit, and those who abandon their faith demonstrate that their initial profession was not genuine.
#     *   **God's Judgment:** God will judge false teachers and those who follow them. He is just and will hold them accountable for leading others astray.
#     *   **The Reality of Spiritual Warfare:** There is an ongoing battle against deceptive forces trying to undermine faith and lead people down destructive paths.
#
# **Old Testament: Daniel 5:1-31**
#
# *   **Summary:** This chapter recounts Belshazzar's feast, where he profanes the sacred vessels taken from the Temple in Jerusalem. During the feast, a mysterious hand appears and writes a message on the wall. Unable to interpret it, Belshazzar summons Daniel, who rebukes the king for his arrogance and failure to learn from Nebuchadnezzar's experience. Daniel interprets the writing: "Mene, Mene, Tekel, Parsin," meaning that God has numbered Belshazzar's kingdom, weighed him on the scales and found him wanting, and divided his kingdom. That very night, Belshazzar is killed, and Darius the Mede takes over the kingdom.
#
# *   **Key Verses:**
#
#     *   Daniel 5:22-23: "But you, Belshazzar, his son, have not humbled yourself, though you knew all this. Instead, you have set yourself up against the Lord of heaven. You had the goblets from his temple brought to you, and you and your nobles, your wives and your concubines drank wine from them. You praised the gods of silver and gold, of bronze, iron, wood and stone, which cannot see or hear or understand. But you did not honor the God who holds in his hand your life and all your ways."
#     *   Daniel 5:30-31: "That very night Belshazzar, king of the Babylonians, was slain, and Darius the Mede took over the kingdom, at the age of sixty-two."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Humility vs. Pride:** The story contrasts the humility of Nebuchadnezzar after his humbling experience with the arrogance of Belshazzar, which led to his downfall.
#     *   **The Sovereignty of God:** God is in control of kingdoms and rulers. He can raise them up and tear them down according to his will.
#     *   **Judgment and Accountability:** God sees all and holds individuals and nations accountable for their actions, especially when they defy him and profane what is sacred.
#     *   **Warning against Profanity:** Treating holy things with disrespect has consequences.
#
# **Proverbs: Proverbs 28:19-20**
#
# *   **Summary:** This passage presents two contrasting proverbs. The first states that those who work their land will have abundant food, but those who chase fantasies (or worthless pursuits) will have abundant poverty. The second states that a trustworthy person will be richly blessed, but one eager to get rich will not go unpunished.
#
# *   **Key Verses:**
#
#     *   Proverbs 28:19: "Those who work their land will have abundant food, but those who chase fantasies will have abundant poverty."
#     *   Proverbs 28:20: "A trustworthy person will be richly blessed, but one eager to get rich will not go unpunished."
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Diligence and Hard Work:** It emphasizes the value of hard work, honest labor, and responsible stewardship of resources.
#     *   **Trustworthiness and Integrity:** It highlights the importance of integrity, honesty, and trustworthiness in our dealings with others.
#     *   **The Dangers of Greed:** It warns against the pursuit of wealth through dishonest or unethical means. Quick riches often lead to ruin.
#     *   **Contentment:** True wealth and satisfaction are found not in chasing fantasies, but in diligent work and trustworthy character.
#
# **Psalms: Psalms 132:1-5**
#
# *   **Summary:** This Psalm is a prayer recalling David's vow to find a suitable place for the Ark of the Covenant to dwell. It speaks of David's zeal and dedication to God, as he was not content to rest or relax until he had found a permanent home for the Ark, symbolizing God's presence, in Jerusalem.
#
# *   **Key Verses:**
#
#     *   Psalm 132:4-5: "I will allow no sleep to my eyes, no slumber to my eyelids, till I find a place for the Lord, a dwelling for the Mighty One of Jacob.”
#
# *   **Spiritual Insights and Themes:**
#
#     *   **Zeal for God's Presence:** David's devotion demonstrates a deep desire for God's presence and a commitment to honoring Him.
#     *   **Prioritizing God's Will:** David's example teaches us to prioritize God's will above our own comfort and personal desires.
#     *   **Worship and Dedication:** It highlights the importance of finding a suitable place for God in our lives and our willingness to dedicate our time, energy, and resources to His service.
#     *   **Persistence in Seeking God:** David's vow reflects a persistent pursuit of God and a determination to fulfill his commitment.
#
#
# [2] YOUR REFLECTION & AFFIRMATION
# ----------------------------------------------------------------------
# Your Reflection:
# God is awesome
#
# Here's a personalized response and prayer based on the devotion summary and the user's reflection:
#
# **Your Affirmation**
#
# Yes, God *is* awesome! That simple statement encapsulates the profound truths we explored today. It’s amazing how each of these passages – from warnings about false teachers to Belshazzar's pride and David's zeal – points back to the same truth: God's power, justice, and love are unmatched. Keeping that at the center of our lives and decisions helps us navigate the world with wisdom and grace. You're right to focus on His awesomeness - it's the foundation of everything! Let that truth be your guide and comfort today.
#
# **Today's Prayer**
#
# Heavenly Father, thank you for your awesome power and grace, so clearly displayed throughout Scripture. We echo the simple, yet profound truth: "God is awesome!"
#
# Lord, help us to be discerning, as Peter warned, to recognize and reject false teachings that might lead us astray. Protect us from arrogance and pride, remembering Belshazzar's fate. Let us learn from the past and humble ourselves before you, acknowledging your sovereignty over all things.
#
# Grant us the diligence and trustworthiness described in Proverbs. May we be diligent in our work and ethical in our dealings, trusting that true riches come from honest labor and a commitment to integrity.
#
# Instill in us the same zeal for your presence that David had. Help us prioritize you in our lives, seeking to honor you in all that we do. Let us not be content until we have found a suitable place for you to dwell within our hearts and in our actions.
#
# Lord, guide us each day. May your awesomeness inspire us to live lives worthy of your calling. In Jesus' name, Amen.
#
#
# [3] WORSHIP SONGS
# ----------------------------------------------------------------------
# Okay, here are 6 worship songs that align with the themes found in the devotion passages, the user's reflection, and the prayer provided:
#
# 🎵 **"Awesome God"** - Rich Mullins
#    Theme: God's incredible power and majesty; a direct reflection of the "God is Awesome!" sentiment.
#    https://www.youtube.com/results?search_query=Awesome+God+Rich+Mullins+worship
#
# 🎵 **"King of My Heart"** - Bethel Music
#    Theme: Prioritizing God in your life, similar to David's zeal, and acknowledging God's sovereignty and goodness.
#    https://www.youtube.com/results?search_query=King+of+My+Heart+Bethel+worship
#
# 🎵 **"Build My Life"** - Housefires
#    Theme: Building your life upon a solid foundation of faith and being trustworthy, reflecting the Proverbs passage. Acknowledges that God is the only secure foundation.
#    https://www.youtube.com/results?search_query=Build+My+Life+Housefires+worship
#
# 🎵 **"What a Beautiful Name"** - Hillsong Worship
#    Theme: The power and majesty of God's name, especially the name of Jesus; humbling yourself before God and recognizing His supreme authority.
#    https://www.youtube.com/results?search_query=What+a+Beautiful+Name+Hillsong+worship
#
# 🎵 **"Lord, I Need You"** - Matt Maher
#    Theme: Dependence on God, humbling yourself before Him, and acknowledging your need for His guidance and strength, especially in times of temptation to follow false teachings.
#    https://www.youtube.com/results?search_query=Lord+I+Need+You+Matt+Maher+worship
#
# 🎵 **"Great Are You Lord"** - All Sons & Daughters
#    Theme: Acknowledging God's greatness and sovereignty, giving Him praise for His mighty works, and trusting in His faithfulness. Reflects the themes of humility and awe.
#    https://www.youtube.com/results?search_query=Great+Are+You+Lord+All+Sons+&+Daughters+worship
#
#
# ======================================================================
# ✓ DEVOTION AGENT WORKFLOW COMPLETED SUCCESSFULLY
# ======================================================================
